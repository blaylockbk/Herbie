# %% [markdown]
# **Brian Blaylock**
# *July 20, 2021*
#
# # GFS Data
# The product names are not as simple as the HRRR dataset, but we can still get GFS data.

# %%
from herbie.archive import Herbie
from toolbox.cartopy_tools import common_features, pc
from paint.standard2 import cm_tmp

import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# %%
H = Herbie(DATE='2021-07-19', 
           model='gfs', 
           field='pgrb2.0p25')
# Out:
# 🏋🏻‍♂️ Found 2021-Jul-19 00:00 UTC F00 GFS pgrb2.0p25 GRIB2 file from aws and index file from aws.

# %%
x = H.xarray('TMP:2 m above')
# Out:
# 📇 Download subset: GFS model pgrb2.0p25 fields run at 2021-Jul-19 00:00 UTC F00
#  cURL from https://noaa-gfs-bdp-pds.s3.amazonaws.com/gfs.20210719/00/atmos/gfs.t00z.pgrb2.0p25.f000
#    1: GRIB_message=580 TMP:2 m above ground:anl
#    2: GRIB_message=584 APTMP:2 m above ground:anl

# %%
ax = common_features(crs=x.herbie.crs)
p = ax.pcolormesh(x.longitude, x.latitude, x.t2m, 
              transform=pc, 
              **cm_tmp(units='K').cmap_kwargs)
plt.colorbar(p, ax=ax, 
             orientation='horizontal', pad=.05,
             **cm_tmp(units='K').cbar_kwargs)

ax.set_title(x.t2m.GRIB_name, loc='right')
ax.set_title(f"GFS", loc='left')
# Out:
# Text(0.0, 1.0, 'GFS')

# %%
ax = common_features(crs=ccrs.Geostationary(central_longitude=-100))

p = ax.pcolormesh(x.longitude, x.latitude, x.t2m, 
              transform=pc, 
              **cm_tmp(units='K').cmap_kwargs)
plt.colorbar(p, ax=ax, 
             orientation='horizontal', pad=.05,
             **cm_tmp(units='K').cbar_kwargs)

ax.set_title(x.t2m.GRIB_name, loc='right')
ax.set_title(f"GFS", loc='left')
# Out:
# Text(0.0, 1.0, 'GFS')
