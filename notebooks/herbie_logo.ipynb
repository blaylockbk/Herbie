# %%
from herbie.misc import HerbieLogo, HerbieColors, HerbieLogo2, plt

# %%
HerbieLogo()
plt.savefig('../docs/_static/HerbieLogo.png', transparent=False, bbox_inches='tight')
plt.savefig('../docs/_static/HerbieLogo_transparent.png', transparent=True, bbox_inches='tight')

# %%
HerbieLogo(white_line=True)
plt.savefig('../docs/_static/HerbieLogo_w.png', transparent=False, bbox_inches='tight')
plt.savefig('../docs/_static/HerbieLogo_w_transparent.png', transparent=True, bbox_inches='tight')

# %%
HerbieLogo2()
plt.savefig('../docs/_static/HerbieLogo2.png', transparent=False, bbox_inches='tight')
plt.savefig('../docs/_static/HerbieLogo2_transparent.png', transparent=True, bbox_inches='tight')

# %%
HerbieLogo2(white_line=True)
plt.savefig('../docs/_static/HerbieLogo2_w.png', transparent=False, bbox_inches='tight')
plt.savefig('../docs/_static/HerbieLogo2_w_transparent.png', transparent=True, bbox_inches='tight')
