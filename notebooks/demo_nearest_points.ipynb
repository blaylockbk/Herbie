# %% [markdown]
# # Match Nearest Latitude/Longitude Point to Grid
# This is uses the `herbie.tools.nearest_points` function to find the nearest point to a given latitude and longitude.
#
# In this demonstration, we will make a sounding of HRRR data at points in the US.

# %%
from herbie.archive import Herbie
from herbie.tools import nearest_points

import matplotlib.pyplot as plt
# Out:
# C:\Users\blayl_depgywe\miniconda3\envs\herbie\lib\site-packages\toolbox\cartopy_tools.py:38: UserWarning: Migrate to `cartopy_tools2` for latest updates and features.
#   warnings.warn("Migrate to `cartopy_tools2` for latest updates and features.")

# %%
H = Herbie(
    "2021-10-9",
    model="hrrr",
    product="prs",
)
# Out:
# 🏋🏻‍♂️ Found 2021-Oct-09 00:00 UTC F00 [HRRR] [product=prs] GRIB2 file from aws and index file from aws.

# %%
ds = H.xarray('TMP:2 m', remove_grib=True)
ds
# Out:
# 📇 Download subset: [HRRR] model [prs] product run at 2021-Oct-09 00:00 UTC F00
#  cURL from https://noaa-hrrr-bdp-pds.s3.amazonaws.com/hrrr.20211009/conus/hrrr.t00z.wrfprsf00.grib2
#    1: GRIB_message=616 TMP:2 m above ground:anl
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# C:\Users\BLAYL_~1\AppData\Local\Temp/ipykernel_20964/3990192216.py in <module>
# ----> 1 ds = H.xarray('TMP:2 m', remove_grib=True)
#       2 ds
#
# ~\BB_python\Herbie\herbie\archive.py in xarray(self, searchString, backend_kwargs, remove_grib, **download_kwargs)
#     768
#     769             # Removes file
# --> 770             local_file.unlink()
#     771
#     772             Hxr = new
#
# ~\miniconda3\envs\herbie\lib\pathlib.py in unlink(self, missing_ok)
#    1352         """
#    1353         try:
# -> 1354             self._accessor.unlink(self)
#    1355         except FileNotFoundError:
# ...

# %%
ds = H.xarray('TMP:(1|2)00 mb', remove_grib=True)
ds
# Out:
# C:\Users\blayl_depgywe\BB_python\Herbie\herbie\archive.py:517: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   logic = columns_to_search.str.contains(searchString)
# C:\Users\blayl_depgywe\BB_python\Herbie\herbie\archive.py:517: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   logic = columns_to_search.str.contains(searchString)
# <xarray.Dataset>
# Dimensions:              (isobaricInhPa: 2, y: 1059, x: 1799)
# Coordinates:
#     time                 datetime64[ns] 2021-10-09
#     step                 timedelta64[ns] 00:00:00
#   * isobaricInhPa        (isobaricInhPa) float64 200.0 100.0
#     latitude             (y, x) float64 ...
#     longitude            (y, x) float64 ...
#     valid_time           datetime64[ns] ...
# Dimensions without coordinates: y, x
# Data variables:
#     t                    (isobaricInhPa, y, x) float32 ...
#     gribfile_projection  object None
# Attributes:
# ...

# %%
ds.latitude[9,9]
# Out:
# <xarray.DataArray 'latitude' ()>
# array(21.42492)
# Coordinates:
#     time        datetime64[ns] 2021-10-09
#     step        timedelta64[ns] 00:00:00
#     latitude    float64 ...
#     longitude   float64 ...
#     valid_time  datetime64[ns] 2021-10-09
# Attributes:
#     units:          degrees_north
#     standard_name:  latitude
#     long_name:      latitude

# %%
open(f, "r").close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\BLAYL_~1\AppData\Local\Temp/ipykernel_12988/688341391.py in <module>
# ----> 1 open(f, "r").close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\blayl_depgywe\\data\\hrrr\\20211009\\hrrr.t00z.wrfprsf00.grib2.subset_8746b7e5d534efa196e92e53c61ec747f4c936a5'

# %%
backend_kwargs = {}
backend_kwargs.setdefault("indexpath", "")
backend_kwargs.setdefault(
    "read_keys", ["parameterName", "parameterUnits", "stepRange"]
)
backend_kwargs.setdefault("errors", "raise")
# Out:
# 'raise'

# %%
import cfgrib

# %%
searchString = 'TMP:2 m'
FILE = H.get_localFilePath(searchString=searchString)
FILE
# Out:
# WindowsPath('C:/Users/blayl_depgywe/data/hrrr/20211009/hrrr.t00z.wrfprsf00.grib2.subset_8746b7e5d534efa196e92e53c61ec747f4c936a5')

# %%
with cfgrib.open_datasets(FILE, backend_kwargs=backend_kwargs) as ds:
    print(ds)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\BLAYL_~1\AppData\Local\Temp/ipykernel_8024/3747120737.py in <module>
# ----> 1 with cfgrib.open_datasets(FILE, backend_kwargs=backend_kwargs) as ds:
#       2     print(ds)
#
# AttributeError: __enter__

# %%
Hxr = cfgrib.open_datasets(
            FILE,
            backend_kwargs=backend_kwargs,
        )

# %%
Hxr[0].close()

# %%
new = Hxr.copy()

# %%
new[0].latitude[9,8]
# Out:
# <xarray.DataArray 'latitude' ()>
# array(21.417963)
# Coordinates:
#     time               datetime64[ns] 2021-10-09
#     step               timedelta64[ns] 00:00:00
#     heightAboveGround  float64 2.0
#     latitude           float64 ...
#     longitude          float64 ...
#     valid_time         datetime64[ns] 2021-10-09
# Attributes:
#     units:          degrees_north
#     standard_name:  latitude
#     long_name:      latitude

# %%
Hxr
# Out:
# [<xarray.Dataset>
#  Dimensions:            (y: 1059, x: 1799)
#  Coordinates:
#      time               datetime64[ns] 2021-10-09
#      step               timedelta64[ns] 00:00:00
#      heightAboveGround  float64 2.0
#      latitude           (y, x) float64 ...
#      longitude          (y, x) float64 ...
#      valid_time         datetime64[ns] ...
#  Dimensions without coordinates: y, x
#  Data variables:
#      t2m                (y, x) float32 ...
#  Attributes:
#      GRIB_edition:            2
#      GRIB_centre:             kwbc
#      GRIB_centreDescription:  US National Weather Service - NCEP
#      GRIB_subCentre:          0
#      Conventions:             CF-1.7
#      institution:             US National Weather Service - NCEP ]

# %%
H.get_localFilePath(searchString=searchString)
# Out:
# WindowsPath('C:/Users/blayl_depgywe/data/hrrr/20211009/hrrr.t00z.wrfprsf00.grib2.subset_8746b7e5d534efa196e92e53c61ec747f4c936a5')

# %%
import xarray as xr

# %%
a = xr.open_dataset(FILE, 
                    engine='cfgrib', 
                    backend_kwargs=backend_kwargs)
a
# Out:
# <xarray.Dataset>
# Dimensions:            (y: 1059, x: 1799)
# Coordinates:
#     time               datetime64[ns] ...
#     step               timedelta64[ns] ...
#     heightAboveGround  float64 ...
#     latitude           (y, x) float64 ...
#     longitude          (y, x) float64 ...
#     valid_time         datetime64[ns] ...
# Dimensions without coordinates: y, x
# Data variables:
#     t2m                (y, x) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2021-10-09T08:31 GRIB to CDM+CF via cfgrib-0.9.9...

# %%
a.close()

# %%
a.latitude[9,9]
# Out:
# <xarray.DataArray 'latitude' ()>
# array(21.42492)
# Coordinates:
#     time               datetime64[ns] 2021-10-09
#     step               timedelta64[ns] 00:00:00
#     heightAboveGround  float64 2.0
#     latitude           float64 ...
#     longitude          float64 ...
#     valid_time         datetime64[ns] 2021-10-09
# Attributes:
#     units:          degrees_north
#     standard_name:  latitude
#     long_name:      latitude

# %%
a.load()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\BLAYL_~1\AppData\Local\Temp/ipykernel_8024/2889823502.py in <module>
# ----> 1 a.load()
#
# ~\miniconda3\envs\herbie\lib\site-packages\xarray\core\dataset.py in load(self, **kwargs)
#     871         for k, v in self.variables.items():
#     872             if k not in lazy_data:
# --> 873                 v.load()
#     874
#     875         return self
#
# ~\miniconda3\envs\herbie\lib\site-packages\xarray\core\variable.py in load(self, **kwargs)
#     449             self._data = as_compatible_data(self._data.compute(**kwargs))
#     450         elif not is_duck_array(self._data):
# --> 451             self._data = np.asarray(self._data)
#     452         return self
#     453
#
# ~\miniconda3\envs\herbie\lib\site-packages\xarray\core\indexing.py in __array__(self, dtype)
#     546
# ...
