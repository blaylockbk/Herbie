# %% [markdown]
# **Brian Blaylock**
# *July 20, 2022*
#
# # New `FastHerbie()` Class
# - uses multithreading to create many Herbie objects: `fh = FastHerbie(DATES)`.
# - method for downloading those Herbie objects `fh.download()`
# - method for opening that data with xarray `fh.xarray()`

# %%
from herbie import FastHerbie
import pandas as pd

# %% [markdown]
# ### HRRR

# %%
# Create a range of dates
DATES = pd.date_range('2022-01-01', '2022-01-01 06:00', freq='1H')

# Make Fast Herbie Object. Essentially, this makes a list of many Herbie objects.
fh = FastHerbie(DATES, model='hrrr', fxx=[0])

fh.objects
# Out:
# [▌▌Herbie HRRR model sfc product initialized 2022-Jan-01 00:00 UTC F00 ┊ source=local,
#  ▌▌Herbie HRRR model sfc product initialized 2022-Jan-01 01:00 UTC F00 ┊ source=local,
#  ▌▌Herbie HRRR model sfc product initialized 2022-Jan-01 02:00 UTC F00 ┊ source=local,
#  ▌▌Herbie HRRR model sfc product initialized 2022-Jan-01 03:00 UTC F00 ┊ source=aws,
#  ▌▌Herbie HRRR model sfc product initialized 2022-Jan-01 04:00 UTC F00 ┊ source=aws,
#  ▌▌Herbie HRRR model sfc product initialized 2022-Jan-01 05:00 UTC F00 ┊ source=aws,
#  ▌▌Herbie HRRR model sfc product initialized 2022-Jan-01 06:00 UTC F00 ┊ source=aws]

# %%
# Download/Read Data with Xarray
ds = fh.xarray("TMP:2 m")
ds
# Out:
# <xarray.Dataset>
# Dimensions:              (time: 7, y: 1059, x: 1799)
# Coordinates:
#   * time                 (time) datetime64[ns] 2022-01-01 ... 2022-01-01T06:0...
#     step                 timedelta64[ns] 00:00:00
#     heightAboveGround    float64 2.0
#     latitude             (y, x) float64 21.14 21.15 21.15 ... 47.86 47.85 47.84
#     longitude            (y, x) float64 237.3 237.3 237.3 ... 299.0 299.0 299.1
#     valid_time           (time) datetime64[ns] 2022-01-01 ... 2022-01-01T06:0...
# Dimensions without coordinates: y, x
# Data variables:
#     t2m                  (time, y, x) float32 292.6 292.6 292.6 ... 274.2 274.2
#     gribfile_projection  object None
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
# ...

# %% [markdown]
# ### GFS

# %%
DATES = pd.date_range('2022-01-01', '2022-01-02', freq='6H')

# Make Fast Herbie Object
fh = FastHerbie(DATES, model='gfs', fxx=[0])
fh.objects
# Out:
# [▌▌Herbie GFS model pgrb2.0p25 product initialized 2022-Jan-01 00:00 UTC F00 ┊ source=aws,
#  ▌▌Herbie GFS model pgrb2.0p25 product initialized 2022-Jan-01 06:00 UTC F00 ┊ source=aws,
#  ▌▌Herbie GFS model pgrb2.0p25 product initialized 2022-Jan-01 12:00 UTC F00 ┊ source=aws,
#  ▌▌Herbie GFS model pgrb2.0p25 product initialized 2022-Jan-01 18:00 UTC F00 ┊ source=aws,
#  ▌▌Herbie GFS model pgrb2.0p25 product initialized 2022-Jan-02 00:00 UTC F00 ┊ source=aws]

# %%
ds = fh.xarray(":TMP:2 m above ground")
ds
# Out:
# <xarray.Dataset>
# Dimensions:              (time: 5, latitude: 721, longitude: 1440)
# Coordinates:
#   * time                 (time) datetime64[ns] 2022-01-01 ... 2022-01-02
#     step                 timedelta64[ns] 00:00:00
#     heightAboveGround    float64 2.0
#   * latitude             (latitude) float64 90.0 89.75 89.5 ... -89.75 -90.0
#   * longitude            (longitude) float64 0.0 0.25 0.5 ... 359.2 359.5 359.8
#     valid_time           (time) datetime64[ns] 2022-01-01 ... 2022-01-02
# Data variables:
#     t2m                  (time, latitude, longitude) float32 243.3 ... 247.3
#     gribfile_projection  object None
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     model:                   gfs
# ...
