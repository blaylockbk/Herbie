# %% [markdown]
# # Issue [#41](https://github.com/blaylockbk/Herbie/issues/41)

# %%
from herbie.archive import Herbie

# %%
H = Herbie(
    '2021-07-19',
    model='hrrr',
    product='nat'
)
# Out:
# 🏋🏻‍♂️ Found 2021-Jul-19 00:00 UTC F00 [HRRR] [product=nat] GRIB2 file from aws and index file from aws.

# %%
ds = H.xarray(":(?:U|V)GRD:[0-9]+ hybrid")
ds
# Out:
# 📇 Download subset: [HRRR] model [nat] product run at 2021-Jul-19 00:00 UTC F00
#  cURL from https://noaa-hrrr-bdp-pds.s3.amazonaws.com/hrrr.20210719/conus/hrrr.t00z.wrfnatf00.grib2
#    1: GRIB_message=16  :UGRD:1 hybrid level:anl
#    2: GRIB_message=17  :VGRD:1 hybrid level:anl
#    3: GRIB_message=36  :UGRD:2 hybrid level:anl
#    4: GRIB_message=37  :VGRD:2 hybrid level:anl
#    5: GRIB_message=56  :UGRD:3 hybrid level:anl
#    6: GRIB_message=57  :VGRD:3 hybrid level:anl
#    7: GRIB_message=76  :UGRD:4 hybrid level:anl
#    8: GRIB_message=77  :VGRD:4 hybrid level:anl
#    9: GRIB_message=96  :UGRD:5 hybrid level:anl
#   10: GRIB_message=97  :VGRD:5 hybrid level:anl
#   11: GRIB_message=116 :UGRD:6 hybrid level:anl
#   12: GRIB_message=117 :VGRD:6 hybrid level:anl
#   13: GRIB_message=136 :UGRD:7 hybrid level:anl
#   14: GRIB_message=137 :VGRD:7 hybrid level:anl
#   15: GRIB_message=156 :UGRD:8 hybrid level:anl
#   16: GRIB_message=157 :VGRD:8 hybrid level:anl
# ...

# %% [markdown]
# ---

# %%
H.read_idx()
# Out:
#               start_byte   end_byte                range reference_time  \
# grib_message
# 1.0                    0    2215347            0-2215347     2021-07-19
# 2.0              2215347    2232632      2215347-2232632     2021-07-19
# 3.0              2232632    2232820      2232632-2232820     2021-07-19
# 4.0              2232820    2470892      2232820-2470892     2021-07-19
# 5.0              2470892    2471160      2470892-2471160     2021-07-19
# ...                  ...        ...                  ...            ...
# 1129.0         708146026  708146259  708146026-708146259     2021-07-19
# 1130.0         708146259  709848039  708146259-709848039     2021-07-19
# 1131.0         709848039  711527472  709848039-711527472     2021-07-19
# 1132.0         711527472  713115612  711527472-713115612     2021-07-19
# 1133.0         713115612                      713115612-     2021-07-19
#
#              valid_time variable              level forecast_time  \
# grib_message
# ...

# %%
df = H.read_idx(":(U|V)GRD:[0-9]+ hybrid")
df
# Out:
# /p/home/blaylock/BB_python/Herbie/herbie/archive.py:686: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   logic = df.search_this.str.contains(searchString)
#               start_byte   end_byte                range reference_time  \
# grib_message
# 16.0             8981169   10113298     8981169-10113298     2021-07-19
# 17.0            10113298   11198296    10113298-11198296     2021-07-19
# 36.0            22395629   23538068    22395629-23538068     2021-07-19
# 37.0            23538068   24629527    23538068-24629527     2021-07-19
# 56.0            36066697   37195947    36066697-37195947     2021-07-19
# ...                  ...        ...                  ...            ...
# 957.0          562591871  563257915  562591871-563257915     2021-07-19
# 976.0          573444456  574163729  573444456-574163729     2021-07-19
# ...

# %%
df.level
# Out:
# grib_message
# 16.0      1 hybrid level
# 17.0      1 hybrid level
# 36.0      2 hybrid level
# 37.0      2 hybrid level
# 56.0      3 hybrid level
#               ...
# 957.0    48 hybrid level
# 976.0    49 hybrid level
# 977.0    49 hybrid level
# 996.0    50 hybrid level
# 997.0    50 hybrid level
# Name: level, Length: 100, dtype: object

# %%
ds = H.xarray(":(U|V)GRD:[0-9]+ hybrid")
# Out:
# /p/home/blaylock/BB_python/Herbie/herbie/archive.py:686: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   logic = df.search_this.str.contains(searchString)
# /p/home/blaylock/BB_python/Herbie/herbie/archive.py:686: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   logic = df.search_this.str.contains(searchString)
# /p/home/blaylock/BB_python/Herbie/herbie/archive.py:686: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   logic = df.search_this.str.contains(searchString)
# 📇 Download subset: [HRRR] model [nat] product run at 2021-Jul-19 00:00 UTC F00
#  cURL from https://noaa-hrrr-bdp-pds.s3.amazonaws.com/hrrr.20210719/conus/hrrr.t00z.wrfnatf00.grib2
#    1: GRIB_message=16  :UGRD:1 hybrid level:anl
# ...

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:              (hybrid: 50, y: 1059, x: 1799)
# Coordinates:
#     time                 datetime64[ns] 2021-07-19
#     step                 timedelta64[ns] 00:00:00
#   * hybrid               (hybrid) float64 1.0 2.0 3.0 4.0 ... 48.0 49.0 50.0
#     latitude             (y, x) float64 21.14 21.15 21.15 ... 47.86 47.85 47.84
#     longitude            (y, x) float64 237.3 237.3 237.3 ... 299.0 299.0 299.1
#     valid_time           datetime64[ns] 2021-07-19
# Dimensions without coordinates: y, x
# Data variables:
#     u                    (hybrid, y, x) float32 -5.958 -5.958 ... -7.985 -8.048
#     v                    (hybrid, y, x) float32 -4.403 -4.466 ... -5.593 -5.593
#     gribfile_projection  object None
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
# ...

# %%
dss = H.xarray(":(U|V)GRD:")
# Out:
# /p/home/blaylock/BB_python/Herbie/herbie/archive.py:686: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   logic = df.search_this.str.contains(searchString)
# /p/home/blaylock/BB_python/Herbie/herbie/archive.py:686: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   logic = df.search_this.str.contains(searchString)
# /p/home/blaylock/BB_python/Herbie/herbie/archive.py:686: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   logic = df.search_this.str.contains(searchString)
# 📇 Download subset: [HRRR] model [nat] product run at 2021-Jul-19 00:00 UTC F00
#  cURL from https://noaa-hrrr-bdp-pds.s3.amazonaws.com/hrrr.20210719/conus/hrrr.t00z.wrfnatf00.grib2
#    1: GRIB_message=16  :UGRD:1 hybrid level:anl
# ...

# %%
len(dss)
# Out:
# 3

# %%
dss[2]
# Out:
# <xarray.Dataset>
# Dimensions:              (hybrid: 50, y: 1059, x: 1799)
# Coordinates:
#     time                 datetime64[ns] 2021-07-19
#     step                 timedelta64[ns] 00:00:00
#   * hybrid               (hybrid) float64 1.0 2.0 3.0 4.0 ... 48.0 49.0 50.0
#     latitude             (y, x) float64 21.14 21.15 21.15 ... 47.86 47.85 47.84
#     longitude            (y, x) float64 237.3 237.3 237.3 ... 299.0 299.0 299.1
#     valid_time           datetime64[ns] 2021-07-19
# Dimensions without coordinates: y, x
# Data variables:
#     u                    (hybrid, y, x) float32 -5.958 -5.958 ... -7.985 -8.048
#     v                    (hybrid, y, x) float32 -4.403 -4.466 ... -5.593 -5.593
#     gribfile_projection  object None
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
# ...

# %%
H.download()
# Out:
# ✅ Success! Downloaded HRRR from aws
# 	src: https://noaa-hrrr-bdp-pds.s3.amazonaws.com/hrrr.20210719/conus/hrrr.t00z.wrfnatf00.grib2
# 	dst: /p/cwfs/blaylock/data/hrrr/20210719/hrrr.t00z.wrfnatf00.grib2

# %%
H.xarray(":(?:U|V)GRD:[0-9]+ hybrid")
# Out:
# 📇 Download subset: [HRRR] model [nat] product run at 2021-Jul-19 00:00 UTC F00
#  cURL from https://noaa-hrrr-bdp-pds.s3.amazonaws.com/hrrr.20210719/conus/hrrr.t00z.wrfnatf00.grib2
#    1: GRIB_message=16  :UGRD:1 hybrid level:anl
#    2: GRIB_message=17  :VGRD:1 hybrid level:anl
#    3: GRIB_message=36  :UGRD:2 hybrid level:anl
#    4: GRIB_message=37  :VGRD:2 hybrid level:anl
#    5: GRIB_message=56  :UGRD:3 hybrid level:anl
#    6: GRIB_message=57  :VGRD:3 hybrid level:anl
#    7: GRIB_message=76  :UGRD:4 hybrid level:anl
#    8: GRIB_message=77  :VGRD:4 hybrid level:anl
#    9: GRIB_message=96  :UGRD:5 hybrid level:anl
#   10: GRIB_message=97  :VGRD:5 hybrid level:anl
#   11: GRIB_message=116 :UGRD:6 hybrid level:anl
#   12: GRIB_message=117 :VGRD:6 hybrid level:anl
#   13: GRIB_message=136 :UGRD:7 hybrid level:anl
#   14: GRIB_message=137 :VGRD:7 hybrid level:anl
#   15: GRIB_message=156 :UGRD:8 hybrid level:anl
#   16: GRIB_message=157 :VGRD:8 hybrid level:anl
# ...

# %%
Hp = Herbie(
    '2021-07-19',
    model='hrrr',
    product='prs'
)
# Out:
# 🏋🏻‍♂️ Found 2021-Jul-19 00:00 UTC F00 [HRRR] [product=prs] GRIB2 file from aws and index file from aws.

# %%
Hp.read_idx(":(?:U|V)GRD:[0-9]+ mb")
# Out:
#               start_byte   end_byte                range reference_time  \
# grib_message
# 7.0              2785048    3358247      2785048-3358247     2021-07-19
# 8.0              3358247    3920186      3358247-3920186     2021-07-19
# 21.0             7146396    7726179      7146396-7726179     2021-07-19
# 22.0             7726179    8290359      7726179-8290359     2021-07-19
# 35.0            11872454   12457060    11872454-12457060     2021-07-19
# ...                  ...        ...                  ...            ...
# 512.0          246341533  246972323  246341533-246972323     2021-07-19
# 525.0          253560874  254200235  253560874-254200235     2021-07-19
# 526.0          254200235  254820812  254200235-254820812     2021-07-19
# 538.0          260649858  261280139  260649858-261280139     2021-07-19
# 539.0          261280139  261897275  261280139-261897275     2021-07-19
#
#              valid_time variable    level forecast_time        search_this
# grib_message
# ...
