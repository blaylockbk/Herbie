# %%
from herbie.archive import Herbie

# %%
H = Herbie('2022-04-07 00:00', model='hrrr', product='subh', fxx=2)
# Out:
# 🏋🏻‍♂️ Found 2022-Apr-07 00:00 UTC F02 [HRRR] [product=subh] GRIB2 file from aws and index file from aws.

# %%
H.read_idx(searchString="TMP")
# Out:
#      grib_message  start_byte   end_byte                range reference_time  \
# 13             14     9886727   11088620     9886727-11088620     2022-04-07
# 62             63    56453866   57653955    56453866-57653955     2022-04-07
# 111           112   102212116  103408883  102212116-103408883     2022-04-07
# 160           161   147602021  148795614  147602021-148795614     2022-04-07
#
#              valid_time variable             level forecast_time  \
# 13  2022-04-07 02:00:00      TMP  2 m above ground   75 min fcst
# 62  2022-04-07 02:00:00      TMP  2 m above ground   90 min fcst
# 111 2022-04-07 02:00:00      TMP  2 m above ground  105 min fcst
# 160 2022-04-07 02:00:00      TMP  2 m above ground  120 min fcst
#
#                             search_this
# 13    :TMP:2 m above ground:75 min fcst
# 62    :TMP:2 m above ground:90 min fcst
# 111  :TMP:2 m above ground:105 min fcst
# 160  :TMP:2 m above ground:120 min fcst

# %%
ds = H.xarray("TMP")
# Out:
# 📇 Download subset: [HRRR] model [subh] product run at 2022-Apr-07 00:00 UTC F02
#  cURL from https://noaa-hrrr-bdp-pds.s3.amazonaws.com/hrrr.20220407/conus/hrrr.t00z.wrfsubhf02.grib2
#   14  :TMP:2 m above ground:75 min fcst
#   63  :TMP:2 m above ground:90 min fcst
#   112 :TMP:2 m above ground:105 min fcst
#   161 :TMP:2 m above ground:120 min fcst
# 💾 Saved the above subset to /p/cwfs/blaylock/data/hrrr/20220407/hrrr.t00z.wrfsubhf02.grib2.subset_7cf1d3e2b93b60bff8910452db0f2ca326834c66
# Note: Returning a list of [2] xarray.Datasets because of multiple hypercubes.

# %%
import xarray as xr
ds_new = xr.concat(ds, dim='step', data_vars=['t2m'])
ds_new
# Out:
# <xarray.Dataset>
# Dimensions:              (step: 4, y: 1059, x: 1799)
# Coordinates:
#     time                 datetime64[ns] 2022-04-07
#   * step                 (step) timedelta64[ns] 01:15:00 01:30:00 ... 02:00:00
#     heightAboveGround    float64 2.0
#     latitude             (y, x) float64 21.14 21.15 21.15 ... 47.86 47.85 47.84
#     longitude            (y, x) float64 237.3 237.3 237.3 ... 299.0 299.0 299.1
#     valid_time           (step) datetime64[ns] 2022-04-07T01:15:00 ... 2022-0...
# Dimensions without coordinates: y, x
# Data variables:
#     t2m                  (step, y, x) float32 291.2 291.2 291.2 ... 272.7 272.7
#     gribfile_projection  object None
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
# ...

# %%
ds[1]
# Out:
# <xarray.Dataset>
# Dimensions:              (y: 1059, x: 1799)
# Coordinates:
#     time                 datetime64[ns] 2022-04-07
#     step                 timedelta64[ns] 02:00:00
#     heightAboveGround    float64 2.0
#     latitude             (y, x) float64 21.14 21.15 21.15 ... 47.86 47.85 47.84
#     longitude            (y, x) float64 237.3 237.3 237.3 ... 299.0 299.0 299.1
#     valid_time           datetime64[ns] 2022-04-07T02:00:00
# Dimensions without coordinates: y, x
# Data variables:
#     t2m                  (y, x) float32 291.3 291.3 291.3 ... 272.7 272.7 272.7
#     gribfile_projection  object None
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     model:                   hrrr
#     product:                 subh
# ...

# %%
z = xr.concat(ds, dim='step', data_vars=['t2m'])
z
# Out:
# <xarray.Dataset>
# Dimensions:              (step: 4, y: 1059, x: 1799)
# Coordinates:
#     time                 datetime64[ns] 2022-04-07
#   * step                 (step) timedelta64[ns] 01:15:00 01:30:00 ... 02:00:00
#     heightAboveGround    float64 2.0
#     latitude             (y, x) float64 21.14 21.15 21.15 ... 47.86 47.85 47.84
#     longitude            (y, x) float64 237.3 237.3 237.3 ... 299.0 299.0 299.1
#     valid_time           (step) datetime64[ns] 2022-04-07T01:15:00 ... 2022-0...
# Dimensions without coordinates: y, x
# Data variables:
#     t2m                  (step, y, x) float32 291.2 291.2 291.2 ... 272.7 272.7
#     gribfile_projection  object None
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
# ...

# %%
z.sel(x=5, y=5).t2m.plot()
