# %% [markdown]
# # Open hypercube in a DataTree
#
# For datasets with multiple hypercubes (different vertical levels), cfgrib returns a list of datasets, but Herbie returns an xarray DataTree with nodes named with the vertical level type.

# %%
from herbie.v2 import Herbie
from datetime import datetime, timedelta

# %%
H = Herbie.HRRR(datetime(2026, 1, 1))
H
# Out:
# HRRR(2026-01-01 00:00 UTC, F00, product='sfc')

# %%
H.inventory("(TMP:2 m|GRD:10 m)")
# Out:
# shape: (3, 8)
# ┌────────────┬────────────┬──────────┬────────────┬────────────┬──────────┬────────────┬───────────┐
# │ grib_messa ┆ start_byte ┆ end_byte ┆ reference_ ┆ source     ┆ variable ┆ level      ┆ forecast_ │
# │ ge         ┆ ---        ┆ ---      ┆ time       ┆ ---        ┆ ---      ┆ ---        ┆ time      │
# │ ---        ┆ i64        ┆ i64      ┆ ---        ┆ str        ┆ str      ┆ str        ┆ ---       │
# │ i64        ┆            ┆          ┆ datetime[μ ┆            ┆          ┆            ┆ str       │
# │            ┆            ┆          ┆ s]         ┆            ┆          ┆            ┆           │
# ╞════════════╪════════════╪══════════╪════════════╪════════════╪══════════╪════════════╪═══════════╡
# │ 71         ┆ 37296495   ┆ 38484381 ┆ 2026-01-01 ┆ https://no ┆ TMP      ┆ 2 m above  ┆ anl       │
# │            ┆            ┆          ┆ 00:00:00   ┆ aa-hrrr-bd ┆          ┆ ground     ┆           │
# │            ┆            ┆          ┆            ┆ p-pds.s3.a ┆          ┆            ┆           │
# │            ┆            ┆          ┆            ┆ …          ┆          ┆            ┆           │
# │ 77         ┆ 44311332   ┆ 46692946 ┆ 2026-01-01 ┆ https://no ┆ UGRD     ┆ 10 m above ┆ anl       │
# │            ┆            ┆          ┆ 00:00:00   ┆ aa-hrrr-bd ┆          ┆ ground     ┆           │
# │            ┆            ┆          ┆            ┆ p-pds.s3.a ┆          ┆            ┆           │
# │            ┆            ┆          ┆            ┆ …          ┆          ┆            ┆           │
# │ 78         ┆ 46692947   ┆ 49074561 ┆ 2026-01-01 ┆ https://no ┆ VGRD     ┆ 10 m above ┆ anl       │
# │            ┆            ┆          ┆ 00:00:00   ┆ aa-hrrr-bd ┆          ┆ ground     ┆           │
# │            ┆            ┆          ┆            ┆ p-pds.s3.a ┆          ┆            ┆           │
# │            ┆            ┆          ┆            ┆ …          ┆          ┆            ┆           │
# └────────────┴────────────┴──────────┴────────────┴────────────┴──────────┴────────────┴───────────┘

# %%
ds = H.xarray("(TMP:2 m|GRD:10 m)")
ds
# Out:
# Downloading subset (3 messages, 2 groups) from  → hrrr.t00z.wrfsfcf00.grib2__subset-c4a6ebe3
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✓ Done (2.1s) → /home/blaylock/herbie-data/hrrr.20260101/conus/hrrr.t00z.wrfsfcf00.grib2__subset-c4a6ebe3
# /home/blaylock/GITHUB/Herbie/.venv/lib/python3.13/site-packages/cfgrib/xarray_store.py:51: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   o = xr.merge([o, ds], **kwargs)
# /home/blaylock/GITHUB/Herbie/.venv/lib/python3.13/site-packages/cfgrib/xarray_store.py:51: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   o = xr.merge([o, ds], **kwargs)
# /home/blaylock/GITHUB/Herbie/.venv/lib/python3.13/site-packages/cfgrib/xarray_store.py:51: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   o = xr.merge([o, ds], **kwargs)
# <xarray.DataTree>
# Group: /
# ├── Group: /heightAboveGround_10
# │       Dimensions:              (y: 1059, x: 1799)
# │       Coordinates:
# │           latitude             (y, x) float64 15MB 21.14 21.15 21.15 ... 47.85 47.84
# │           longitude            (y, x) float64 15MB 237.3 237.3 237.3 ... 299.0 299.1
# │           time                 datetime64[ns] 8B 2026-01-01
# │           step                 timedelta64[ns] 8B 00:00:00
# │           heightAboveGround    float64 8B 10.0
# │           valid_time           datetime64[ns] 8B 2026-01-01
# │           gribfile_projection  object 8B None
# │       Dimensions without coordinates: y, x
# │       Data variables:
# │           u10                  (y, x) float32 8MB 3.351 3.351 3.351 ... 4.351 4.288
# │           v10                  (y, x) float32 8MB 4.038 4.038 4.1 ... 9.413 10.23
# │       Attributes:
# │           GRIB_edition:            2
# │           GRIB_centre:             kwbc
# │           GRIB_centreDescription:  US National Weather Service - NCEP
# │           GRIB_subCentre:          0
# │           Conventions:             CF-1.7
# │           institution:             US National Weather Service - NCEP
# └── Group: /heightAboveGround_2
#         Dimensions:              (y: 1059, x: 1799)
#         Coordinates:
#             latitude             (y, x) float64 15MB 21.14 21.15 21.15 ... 47.85 47.84
#             longitude            (y, x) float64 15MB 237.3 237.3 237.3 ... 299.0 299.1
#             time                 datetime64[ns] 8B 2026-01-01
#             step                 timedelta64[ns] 8B 00:00:00
#             heightAboveGround    float64 8B 2.0
#             valid_time           datetime64[ns] 8B 2026-01-01
#             gribfile_projection  object 8B None
#         Dimensions without coordinates: y, x
#         Data variables:
#             t2m                  (y, x) float32 8MB 295.1 295.1 295.1 ... 270.5 270.5
#         Attributes:
#             GRIB_edition:            2
#             GRIB_centre:             kwbc
#             GRIB_centreDescription:  US National Weather Service - NCEP
#             GRIB_subCentre:          0
#             Conventions:             CF-1.7
#             institution:             US National Weather Service - NCEP

# %%
ds["/heightAboveGround_10"]
# Out:
# <xarray.DataTree 'heightAboveGround_10'>
# Group: /heightAboveGround_10
#     Dimensions:              (y: 1059, x: 1799)
#     Coordinates:
#         latitude             (y, x) float64 15MB 21.14 21.15 21.15 ... 47.85 47.84
#         longitude            (y, x) float64 15MB 237.3 237.3 237.3 ... 299.0 299.1
#         time                 datetime64[ns] 8B 2026-01-01
#         step                 timedelta64[ns] 8B 00:00:00
#         heightAboveGround    float64 8B 10.0
#         valid_time           datetime64[ns] 8B 2026-01-01
#         gribfile_projection  object 8B None
#     Dimensions without coordinates: y, x
#     Data variables:
#         u10                  (y, x) float32 8MB 3.351 3.351 3.351 ... 4.351 4.288
#         v10                  (y, x) float32 8MB 4.038 4.038 4.1 ... 9.413 10.23
#     Attributes:
#         GRIB_edition:            2
#         GRIB_centre:             kwbc
#         GRIB_centreDescription:  US National Weather Service - NCEP
#         GRIB_subCentre:          0
#         Conventions:             CF-1.7
#         institution:             US National Weather Service - NCEP

# %%
H.inventory("UGRD:.*0 ")
# Out:
# shape: (8, 8)
# ┌────────────┬────────────┬──────────┬────────────┬────────────┬──────────┬────────────┬───────────┐
# │ grib_messa ┆ start_byte ┆ end_byte ┆ reference_ ┆ source     ┆ variable ┆ level      ┆ forecast_ │
# │ ge         ┆ ---        ┆ ---      ┆ time       ┆ ---        ┆ ---      ┆ ---        ┆ time      │
# │ ---        ┆ i64        ┆ i64      ┆ ---        ┆ str        ┆ str      ┆ str        ┆ ---       │
# │ i64        ┆            ┆          ┆ datetime[μ ┆            ┆          ┆            ┆ str       │
# │            ┆            ┆          ┆ s]         ┆            ┆          ┆            ┆           │
# ╞════════════╪════════════╪══════════╪════════════╪════════════╪══════════╪════════════╪═══════════╡
# │ 10         ┆ 4923776    ┆ 5675550  ┆ 2026-01-01 ┆ https://no ┆ UGRD     ┆ 250 mb     ┆ anl       │
# │            ┆            ┆          ┆ 00:00:00   ┆ aa-hrrr-bd ┆          ┆            ┆           │
# │            ┆            ┆          ┆            ┆ p-pds.s3.a ┆          ┆            ┆           │
# │            ┆            ┆          ┆            ┆ …          ┆          ┆            ┆           │
# │ 12         ┆ 6427751    ┆ 7166712  ┆ 2026-01-01 ┆ https://no ┆ UGRD     ┆ 300 mb     ┆ anl       │
# │            ┆            ┆          ┆ 00:00:00   ┆ aa-hrrr-bd ┆          ┆            ┆           │
# │            ┆            ┆          ┆            ┆ p-pds.s3.a ┆          ┆            ┆           │
# │            ┆            ┆          ┆            ┆ …          ┆          ┆            ┆           │
# │ 17         ┆ 10047877   ┆ 10633288 ┆ 2026-01-01 ┆ https://no ┆ UGRD     ┆ 500 mb     ┆ anl       │
# │            ┆            ┆          ┆ 00:00:00   ┆ aa-hrrr-bd ┆          ┆            ┆           │
# │            ┆            ┆          ┆            ┆ p-pds.s3.a ┆          ┆            ┆           │
# │            ┆            ┆          ┆            ┆ …          ┆          ┆            ┆           │
# │ 23         ┆ 13768718   ┆ 14364429 ┆ 2026-01-01 ┆ https://no ┆ UGRD     ┆ 700 mb     ┆ anl       │
# │            ┆            ┆          ┆ 00:00:00   ┆ aa-hrrr-bd ┆          ┆            ┆           │
# │            ┆            ┆          ┆            ┆ p-pds.s3.a ┆          ┆            ┆           │
# │            ┆            ┆          ┆            ┆ …          ┆          ┆            ┆           │
# │ 28         ┆ 17418350   ┆ 18034408 ┆ 2026-01-01 ┆ https://no ┆ UGRD     ┆ 850 mb     ┆ anl       │
# │            ┆            ┆          ┆ 00:00:00   ┆ aa-hrrr-bd ┆          ┆            ┆           │
# │            ┆            ┆          ┆            ┆ p-pds.s3.a ┆          ┆            ┆           │
# │            ┆            ┆          ┆            ┆ …          ┆          ┆            ┆           │
# │ 36         ┆ 23416060   ┆ 24048730 ┆ 2026-01-01 ┆ https://no ┆ UGRD     ┆ 1000 mb    ┆ anl       │
# │            ┆            ┆          ┆ 00:00:00   ┆ aa-hrrr-bd ┆          ┆            ┆           │
# │            ┆            ┆          ┆            ┆ p-pds.s3.a ┆          ┆            ┆           │
# │            ┆            ┆          ┆            ┆ …          ┆          ┆            ┆           │
# │ 60         ┆ 27174444   ┆ 28322812 ┆ 2026-01-01 ┆ https://no ┆ UGRD     ┆ 80 m above ┆ anl       │
# │            ┆            ┆          ┆ 00:00:00   ┆ aa-hrrr-bd ┆          ┆ ground     ┆           │
# │            ┆            ┆          ┆            ┆ p-pds.s3.a ┆          ┆            ┆           │
# │            ┆            ┆          ┆            ┆ …          ┆          ┆            ┆           │
# │ 77         ┆ 44311332   ┆ 46692946 ┆ 2026-01-01 ┆ https://no ┆ UGRD     ┆ 10 m above ┆ anl       │
# │            ┆            ┆          ┆ 00:00:00   ┆ aa-hrrr-bd ┆          ┆ ground     ┆           │
# │            ┆            ┆          ┆            ┆ p-pds.s3.a ┆          ┆            ┆           │
# │            ┆            ┆          ┆            ┆ …          ┆          ┆            ┆           │
# └────────────┴────────────┴──────────┴────────────┴────────────┴──────────┴────────────┴───────────┘

# %%
H.xarray("UGRD:.*0 ")
# Out:
# Downloading subset (8 messages, 8 groups) from  → hrrr.t00z.wrfsfcf00.grib2__subset-04b40511
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✓ Done (4.1s) → /home/blaylock/herbie-data/hrrr.20260101/conus/hrrr.t00z.wrfsfcf00.grib2__subset-04b40511
# <xarray.DataTree>
# Group: /
# ├── Group: /heightAboveGround_80
# │       Dimensions:              (y: 1059, x: 1799)
# │       Coordinates:
# │           latitude             (y, x) float64 15MB 21.14 21.15 21.15 ... 47.85 47.84
# │           longitude            (y, x) float64 15MB 237.3 237.3 237.3 ... 299.0 299.1
# │           time                 datetime64[ns] 8B 2026-01-01
# │           step                 timedelta64[ns] 8B 00:00:00
# │           heightAboveGround    float64 8B 80.0
# │           valid_time           datetime64[ns] 8B 2026-01-01
# │           gribfile_projection  object 8B None
# │       Dimensions without coordinates: y, x
# │       Data variables:
# │           u                    (y, x) float32 8MB 3.819 3.819 3.819 ... 4.569 4.507
# │       Attributes:
# │           GRIB_edition:            2
# │           GRIB_centre:             kwbc
# │           GRIB_centreDescription:  US National Weather Service - NCEP
# │           GRIB_subCentre:          0
# │           Conventions:             CF-1.7
# │           institution:             US National Weather Service - NCEP
# ├── Group: /heightAboveGround_10
# │       Dimensions:              (y: 1059, x: 1799)
# │       Coordinates:
# │           latitude             (y, x) float64 15MB 21.14 21.15 21.15 ... 47.85 47.84
# │           longitude            (y, x) float64 15MB 237.3 237.3 237.3 ... 299.0 299.1
# │           time                 datetime64[ns] 8B 2026-01-01
# │           step                 timedelta64[ns] 8B 00:00:00
# │           heightAboveGround    float64 8B 10.0
# │           valid_time           datetime64[ns] 8B 2026-01-01
# │           gribfile_projection  object 8B None
# │       Dimensions without coordinates: y, x
# │       Data variables:
# │           u10                  (y, x) float32 8MB 3.351 3.351 3.351 ... 4.351 4.288
# │       Attributes:
# │           GRIB_edition:            2
# │           GRIB_centre:             kwbc
# │           GRIB_centreDescription:  US National Weather Service - NCEP
# │           GRIB_subCentre:          0
# │           Conventions:             CF-1.7
# │           institution:             US National Weather Service - NCEP
# └── Group: /isobaricInhPa
#         Dimensions:              (isobaricInhPa: 6, y: 1059, x: 1799)
#         Coordinates:
#           * isobaricInhPa        (isobaricInhPa) float64 48B 1e+03 850.0 ... 300.0 250.0
#             latitude             (y, x) float64 15MB 21.14 21.15 21.15 ... 47.85 47.84
#             longitude            (y, x) float64 15MB 237.3 237.3 237.3 ... 299.0 299.1
#             time                 datetime64[ns] 8B 2026-01-01
#             step                 timedelta64[ns] 8B 00:00:00
#             valid_time           datetime64[ns] 8B 2026-01-01
#             gribfile_projection  object 8B None
#         Dimensions without coordinates: y, x
#         Data variables:
#             u                    (isobaricInhPa, y, x) float32 46MB 4.088 ... 9.988
#         Attributes:
#             GRIB_edition:            2
#             GRIB_centre:             kwbc
#             GRIB_centreDescription:  US National Weather Service - NCEP
#             GRIB_subCentre:          0
#             Conventions:             CF-1.7
#             institution:             US National Weather Service - NCEP
