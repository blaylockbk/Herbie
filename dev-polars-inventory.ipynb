# %%
import polars as pl
from herbie import Herbie
import pandas as pd

# %%
H = Herbie("2025-11-01")
H.idx
# Out:
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2025-Nov-01 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# 'https://noaa-hrrr-bdp-pds.s3.amazonaws.com/hrrr.20251101/conus/hrrr.t00z.wrfsfcf00.grib2.idx'

# %%
# %%time
df = (
    pl.read_csv(
        H.idx,
        has_header=False,
        separator=":",
        new_columns=[
            "grib_message",
            "start_byte",
            "reference_time",
            "variable",
            "level",
            "forecast_time",
        ],
    )
    .with_columns(
        pl.col("reference_time").str.pad_end(14, "0").str.to_datetime("d=%Y%m%d%H%M")
    )
    .insert_column(2, (pl.col("start_byte").shift(-1) - 1).alias("end_byte"))
    .insert_column(
        3,
        pl.concat_str(
            pl.col("start_byte"),
            pl.lit("-"),
            pl.col("end_byte").cast(pl.String).fill_null(""),
        ).alias("byte_range"),
    )
    .insert_column(0, pl.lit(H.idx).alias("url"))
)

# Drop column with all nulls
df = df[[s.name for s in df if not (s.null_count() == df.height)]]
df
# Out:
# CPU times: user 39.2 ms, sys: 19.6 ms, total: 58.7 ms
# Wall time: 362 ms
# shape: (170, 9)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ url       ┆ grib_mess ┆ start_byt ┆ end_byte  ┆ … ┆ reference ┆ variable  ┆ level     ┆ forecast │
# │ ---       ┆ age       ┆ e         ┆ ---       ┆   ┆ _time     ┆ ---       ┆ ---       ┆ _time    │
# │ str       ┆ ---       ┆ ---       ┆ i64       ┆   ┆ ---       ┆ str       ┆ str       ┆ ---      │
# │           ┆ i64       ┆ i64       ┆           ┆   ┆ datetime[ ┆           ┆           ┆ str      │
# │           ┆           ┆           ┆           ┆   ┆ μs]       ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ https://n ┆ 1         ┆ 0         ┆ 334294    ┆ … ┆ 2025-11-0 ┆ REFC      ┆ entire    ┆ anl      │
# │ oaa-hrrr- ┆           ┆           ┆           ┆   ┆ 1         ┆           ┆ atmospher ┆          │
# │ bdp-pds.s ┆           ┆           ┆           ┆   ┆ 00:00:00  ┆           ┆ e         ┆          │
# │ 3.a…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ https://n ┆ 2         ┆ 334295    ┆ 517716    ┆ … ┆ 2025-11-0 ┆ RETOP     ┆ cloud top ┆ anl      │
# │ oaa-hrrr- ┆           ┆           ┆           ┆   ┆ 1         ┆           ┆           ┆          │
# │ bdp-pds.s ┆           ┆           ┆           ┆   ┆ 00:00:00  ┆           ┆           ┆          │
# │ 3.a…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ https://n ┆ 3         ┆ 517717    ┆ 912580    ┆ … ┆ 2025-11-0 ┆ var disci ┆ entire    ┆ anl      │
# │ oaa-hrrr- ┆           ┆           ┆           ┆   ┆ 1         ┆ pline=0   ┆ atmospher ┆          │
# │ bdp-pds.s ┆           ┆           ┆           ┆   ┆ 00:00:00  ┆ center=7  ┆ e         ┆          │
# │ 3.a…      ┆           ┆           ┆           ┆   ┆           ┆ loca…     ┆           ┆          │
# │ https://n ┆ 4         ┆ 912581    ┆ 1203223   ┆ … ┆ 2025-11-0 ┆ VIL       ┆ entire    ┆ anl      │
# │ oaa-hrrr- ┆           ┆           ┆           ┆   ┆ 1         ┆           ┆ atmospher ┆          │
# │ bdp-pds.s ┆           ┆           ┆           ┆   ┆ 00:00:00  ┆           ┆ e         ┆          │
# │ 3.a…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ https://n ┆ 5         ┆ 1203224   ┆ 2610380   ┆ … ┆ 2025-11-0 ┆ VIS       ┆ surface   ┆ anl      │
# │ oaa-hrrr- ┆           ┆           ┆           ┆   ┆ 1         ┆           ┆           ┆          │
# │ bdp-pds.s ┆           ┆           ┆           ┆   ┆ 00:00:00  ┆           ┆           ┆          │
# │ 3.a…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ https://n ┆ 166       ┆ 126934423 ┆ 126934655 ┆ … ┆ 2025-11-0 ┆ ICEC      ┆ surface   ┆ anl      │
# │ oaa-hrrr- ┆           ┆           ┆           ┆   ┆ 1         ┆           ┆           ┆          │
# │ bdp-pds.s ┆           ┆           ┆           ┆   ┆ 00:00:00  ┆           ┆           ┆          │
# │ 3.a…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ https://n ┆ 167       ┆ 126934656 ┆ 128349936 ┆ … ┆ 2025-11-0 ┆ SBT123    ┆ top of    ┆ anl      │
# │ oaa-hrrr- ┆           ┆           ┆           ┆   ┆ 1         ┆           ┆ atmospher ┆          │
# │ bdp-pds.s ┆           ┆           ┆           ┆   ┆ 00:00:00  ┆           ┆ e         ┆          │
# │ 3.a…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ https://n ┆ 168       ┆ 128349937 ┆ 130686198 ┆ … ┆ 2025-11-0 ┆ SBT124    ┆ top of    ┆ anl      │
# │ oaa-hrrr- ┆           ┆           ┆           ┆   ┆ 1         ┆           ┆ atmospher ┆          │
# │ bdp-pds.s ┆           ┆           ┆           ┆   ┆ 00:00:00  ┆           ┆ e         ┆          │
# │ 3.a…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ https://n ┆ 169       ┆ 130686199 ┆ 131986523 ┆ … ┆ 2025-11-0 ┆ SBT113    ┆ top of    ┆ anl      │
# │ oaa-hrrr- ┆           ┆           ┆           ┆   ┆ 1         ┆           ┆ atmospher ┆          │
# │ bdp-pds.s ┆           ┆           ┆           ┆   ┆ 00:00:00  ┆           ┆ e         ┆          │
# │ 3.a…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ https://n ┆ 170       ┆ 131986524 ┆ null      ┆ … ┆ 2025-11-0 ┆ SBT114    ┆ top of    ┆ anl      │
# │ oaa-hrrr- ┆           ┆           ┆           ┆   ┆ 1         ┆           ┆ atmospher ┆          │
# │ bdp-pds.s ┆           ┆           ┆           ┆   ┆ 00:00:00  ┆           ┆ e         ┆          │
# │ 3.a…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
df1 = df.filter(pl.col("variable").is_in(["UGRD", "VGRD"]))
df1
# Out:
# shape: (18, 9)
# ┌────────────┬───────────┬───────────┬──────────┬───┬───────────┬──────────┬───────────┬───────────┐
# │ url        ┆ grib_mess ┆ start_byt ┆ end_byte ┆ … ┆ reference ┆ variable ┆ level     ┆ forecast_ │
# │ ---        ┆ age       ┆ e         ┆ ---      ┆   ┆ _time     ┆ ---      ┆ ---       ┆ time      │
# │ str        ┆ ---       ┆ ---       ┆ i64      ┆   ┆ ---       ┆ str      ┆ str       ┆ ---       │
# │            ┆ i64       ┆ i64       ┆          ┆   ┆ datetime[ ┆          ┆           ┆ str       │
# │            ┆           ┆           ┆          ┆   ┆ μs]       ┆          ┆           ┆           │
# ╞════════════╪═══════════╪═══════════╪══════════╪═══╪═══════════╪══════════╪═══════════╪═══════════╡
# │ https://no ┆ 10        ┆ 4269730   ┆ 5018584  ┆ … ┆ 2025-11-0 ┆ UGRD     ┆ 250 mb    ┆ anl       │
# │ aa-hrrr-bd ┆           ┆           ┆          ┆   ┆ 1         ┆          ┆           ┆           │
# │ p-pds.s3.a ┆           ┆           ┆          ┆   ┆ 00:00:00  ┆          ┆           ┆           │
# │ …          ┆           ┆           ┆          ┆   ┆           ┆          ┆           ┆           │
# │ https://no ┆ 11        ┆ 5018585   ┆ 5754631  ┆ … ┆ 2025-11-0 ┆ VGRD     ┆ 250 mb    ┆ anl       │
# │ aa-hrrr-bd ┆           ┆           ┆          ┆   ┆ 1         ┆          ┆           ┆           │
# │ p-pds.s3.a ┆           ┆           ┆          ┆   ┆ 00:00:00  ┆          ┆           ┆           │
# │ …          ┆           ┆           ┆          ┆   ┆           ┆          ┆           ┆           │
# │ https://no ┆ 12        ┆ 5754632   ┆ 6498788  ┆ … ┆ 2025-11-0 ┆ UGRD     ┆ 300 mb    ┆ anl       │
# │ aa-hrrr-bd ┆           ┆           ┆          ┆   ┆ 1         ┆          ┆           ┆           │
# │ p-pds.s3.a ┆           ┆           ┆          ┆   ┆ 00:00:00  ┆          ┆           ┆           │
# │ …          ┆           ┆           ┆          ┆   ┆           ┆          ┆           ┆           │
# │ https://no ┆ 13        ┆ 6498789   ┆ 7229386  ┆ … ┆ 2025-11-0 ┆ VGRD     ┆ 300 mb    ┆ anl       │
# │ aa-hrrr-bd ┆           ┆           ┆          ┆   ┆ 1         ┆          ┆           ┆           │
# │ p-pds.s3.a ┆           ┆           ┆          ┆   ┆ 00:00:00  ┆          ┆           ┆           │
# │ …          ┆           ┆           ┆          ┆   ┆           ┆          ┆           ┆           │
# │ https://no ┆ 17        ┆ 9405025   ┆ 10001845 ┆ … ┆ 2025-11-0 ┆ UGRD     ┆ 500 mb    ┆ anl       │
# │ aa-hrrr-bd ┆           ┆           ┆          ┆   ┆ 1         ┆          ┆           ┆           │
# │ p-pds.s3.a ┆           ┆           ┆          ┆   ┆ 00:00:00  ┆          ┆           ┆           │
# │ …          ┆           ┆           ┆          ┆   ┆           ┆          ┆           ┆           │
# │ …          ┆ …         ┆ …         ┆ …        ┆ … ┆ …         ┆ …        ┆ …         ┆ …         │
# │ https://no ┆ 37        ┆ 23509355  ┆ 24115064 ┆ … ┆ 2025-11-0 ┆ VGRD     ┆ 1000 mb   ┆ anl       │
# │ aa-hrrr-bd ┆           ┆           ┆          ┆   ┆ 1         ┆          ┆           ┆           │
# │ p-pds.s3.a ┆           ┆           ┆          ┆   ┆ 00:00:00  ┆          ┆           ┆           │
# │ …          ┆           ┆           ┆          ┆   ┆           ┆          ┆           ┆           │
# │ https://no ┆ 60        ┆ 26622182  ┆ 27732612 ┆ … ┆ 2025-11-0 ┆ UGRD     ┆ 80 m      ┆ anl       │
# │ aa-hrrr-bd ┆           ┆           ┆          ┆   ┆ 1         ┆          ┆ above     ┆           │
# │ p-pds.s3.a ┆           ┆           ┆          ┆   ┆ 00:00:00  ┆          ┆ ground    ┆           │
# │ …          ┆           ┆           ┆          ┆   ┆           ┆          ┆           ┆           │
# │ https://no ┆ 61        ┆ 27732613  ┆ 28825678 ┆ … ┆ 2025-11-0 ┆ VGRD     ┆ 80 m      ┆ anl       │
# │ aa-hrrr-bd ┆           ┆           ┆          ┆   ┆ 1         ┆          ┆ above     ┆           │
# │ p-pds.s3.a ┆           ┆           ┆          ┆   ┆ 00:00:00  ┆          ┆ ground    ┆           │
# │ …          ┆           ┆           ┆          ┆   ┆           ┆          ┆           ┆           │
# │ https://no ┆ 77        ┆ 42384646  ┆ 44766260 ┆ … ┆ 2025-11-0 ┆ UGRD     ┆ 10 m      ┆ anl       │
# │ aa-hrrr-bd ┆           ┆           ┆          ┆   ┆ 1         ┆          ┆ above     ┆           │
# │ p-pds.s3.a ┆           ┆           ┆          ┆   ┆ 00:00:00  ┆          ┆ ground    ┆           │
# │ …          ┆           ┆           ┆          ┆   ┆           ┆          ┆           ┆           │
# │ https://no ┆ 78        ┆ 44766261  ┆ 47147875 ┆ … ┆ 2025-11-0 ┆ VGRD     ┆ 10 m      ┆ anl       │
# │ aa-hrrr-bd ┆           ┆           ┆          ┆   ┆ 1         ┆          ┆ above     ┆           │
# │ p-pds.s3.a ┆           ┆           ┆          ┆   ┆ 00:00:00  ┆          ┆ ground    ┆           │
# │ …          ┆           ┆           ┆          ┆   ┆           ┆          ┆           ┆           │
# └────────────┴───────────┴───────────┴──────────┴───┴───────────┴──────────┴───────────┴───────────┘

# %%
df1.with_columns(
    download_group=(pl.col("grib_message").diff().fill_null(1) != 1).cum_sum(),
).group_by("url", "download_group", maintain_order=True).agg(
    pl.col("start_byte").min(),
    pl.col("end_byte").max(),
    pl.col("grib_message"),
    pl.col("variable"),
    pl.col("level"),
).insert_column(
    3,
    pl.concat_str(
        pl.col("start_byte"),
        pl.lit("-"),
        pl.col("end_byte").cast(pl.String).fill_null(""),
    ).alias("byte_range"),
)
# Out:
# shape: (8, 8)
# ┌────────────┬────────────┬────────────┬────────────┬──────────┬───────────┬───────────┬───────────┐
# │ url        ┆ download_g ┆ start_byte ┆ byte_range ┆ end_byte ┆ grib_mess ┆ variable  ┆ level     │
# │ ---        ┆ roup       ┆ ---        ┆ ---        ┆ ---      ┆ age       ┆ ---       ┆ ---       │
# │ str        ┆ ---        ┆ i64        ┆ str        ┆ i64      ┆ ---       ┆ list[str] ┆ list[str] │
# │            ┆ u32        ┆            ┆            ┆          ┆ list[i64] ┆           ┆           │
# ╞════════════╪════════════╪════════════╪════════════╪══════════╪═══════════╪═══════════╪═══════════╡
# │ https://no ┆ 0          ┆ 4269730    ┆ 4269730-72 ┆ 7229386  ┆ [10, 11,  ┆ ["UGRD",  ┆ ["250     │
# │ aa-hrrr-bd ┆            ┆            ┆ 29386      ┆          ┆ … 13]     ┆ "VGRD", … ┆ mb", "250 │
# │ p-pds.s3.a ┆            ┆            ┆            ┆          ┆           ┆ "VGRD"]   ┆ mb", …    │
# │ …          ┆            ┆            ┆            ┆          ┆           ┆           ┆ "300 mb…  │
# │ https://no ┆ 1          ┆ 9405025    ┆ 9405025-10 ┆ 10588422 ┆ [17, 18]  ┆ ["UGRD",  ┆ ["500     │
# │ aa-hrrr-bd ┆            ┆            ┆ 588422     ┆          ┆           ┆ "VGRD"]   ┆ mb", "500 │
# │ p-pds.s3.a ┆            ┆            ┆            ┆          ┆           ┆           ┆ mb"]      │
# │ …          ┆            ┆            ┆            ┆          ┆           ┆           ┆           │
# │ https://no ┆ 2          ┆ 13278275   ┆ 13278275-1 ┆ 14473594 ┆ [23, 24]  ┆ ["UGRD",  ┆ ["700     │
# │ aa-hrrr-bd ┆            ┆            ┆ 4473594    ┆          ┆           ┆ "VGRD"]   ┆ mb", "700 │
# │ p-pds.s3.a ┆            ┆            ┆            ┆          ┆           ┆           ┆ mb"]      │
# │ …          ┆            ┆            ┆            ┆          ┆           ┆           ┆           │
# │ https://no ┆ 3          ┆ 16961021   ┆ 16961021-1 ┆ 18199651 ┆ [28, 29]  ┆ ["UGRD",  ┆ ["850     │
# │ aa-hrrr-bd ┆            ┆            ┆ 8199651    ┆          ┆           ┆ "VGRD"]   ┆ mb", "850 │
# │ p-pds.s3.a ┆            ┆            ┆            ┆          ┆           ┆           ┆ mb"]      │
# │ …          ┆            ┆            ┆            ┆          ┆           ┆           ┆           │
# │ https://no ┆ 4          ┆ 19920258   ┆ 19920258-2 ┆ 21161109 ┆ [32, 33]  ┆ ["UGRD",  ┆ ["925     │
# │ aa-hrrr-bd ┆            ┆            ┆ 1161109    ┆          ┆           ┆ "VGRD"]   ┆ mb", "925 │
# │ p-pds.s3.a ┆            ┆            ┆            ┆          ┆           ┆           ┆ mb"]      │
# │ …          ┆            ┆            ┆            ┆          ┆           ┆           ┆           │
# │ https://no ┆ 5          ┆ 22879925   ┆ 22879925-2 ┆ 24115064 ┆ [36, 37]  ┆ ["UGRD",  ┆ ["1000    │
# │ aa-hrrr-bd ┆            ┆            ┆ 4115064    ┆          ┆           ┆ "VGRD"]   ┆ mb",      │
# │ p-pds.s3.a ┆            ┆            ┆            ┆          ┆           ┆           ┆ "1000     │
# │ …          ┆            ┆            ┆            ┆          ┆           ┆           ┆ mb"]      │
# │ https://no ┆ 6          ┆ 26622182   ┆ 26622182-2 ┆ 28825678 ┆ [60, 61]  ┆ ["UGRD",  ┆ ["80 m    │
# │ aa-hrrr-bd ┆            ┆            ┆ 8825678    ┆          ┆           ┆ "VGRD"]   ┆ above     │
# │ p-pds.s3.a ┆            ┆            ┆            ┆          ┆           ┆           ┆ ground",  │
# │ …          ┆            ┆            ┆            ┆          ┆           ┆           ┆ "80 m ab… │
# │ https://no ┆ 7          ┆ 42384646   ┆ 42384646-4 ┆ 47147875 ┆ [77, 78]  ┆ ["UGRD",  ┆ ["10 m    │
# │ aa-hrrr-bd ┆            ┆            ┆ 7147875    ┆          ┆           ┆ "VGRD"]   ┆ above     │
# │ p-pds.s3.a ┆            ┆            ┆            ┆          ┆           ┆           ┆ ground",  │
# │ …          ┆            ┆            ┆            ┆          ┆           ┆           ┆ "10 m ab… │
# └────────────┴────────────┴────────────┴────────────┴──────────┴───────────┴───────────┴───────────┘

# %%
# Next steps
# 1. Download each item (use multithreading) into temp files
# 2. Join temp files into a single grib2 file
