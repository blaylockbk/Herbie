# %% [markdown]
# # `fxx` parameter renamed to `step`

# %%
from herbie.v2 import Herbie
from datetime import timedelta

# %%
H = Herbie.HRRR("2026-01-01", step=12)
H
# Out:
# HRRR(2026-01-01 00:00 UTC, F12, product='sfc')

# %%
H = Herbie.HRRR("2026-01-01", step=timedelta(hours=6))
H
# Out:
# HRRR(2026-01-01 00:00 UTC, F06, product='sfc')

# %%
H = Herbie.HRRR("2026-01-01", step=timedelta(hours=12), product="pressure")
H
# Out:
# HRRR(2026-01-01 00:00 UTC, F12, product='prs')

# %%
H = Herbie.HRRR("2026-01-01", step=12)
H
# Out:
# HRRR(2026-01-01 00:00 UTC, F12, product='sfc')

# %%
H = Herbie.HRRR("2026-01-01", step=timedelta(hours=12))
H
# Out:
# HRRR(2026-01-01 00:00 UTC, F12, product='sfc')
