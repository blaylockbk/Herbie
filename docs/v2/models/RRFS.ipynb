# %% [markdown]
# # RRFS and REFS

# %%
from herbie.v2 import RRFS

# %%
H = RRFS("2026-01-01", step=0)
H.resolve()
# Out:
# RRFS(2026-01-01 00:00 UTC, F00, product='prslev', domain='conus', step=0, source=None)
