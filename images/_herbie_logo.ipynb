# %% [markdown]
# # Herbie Logo
#
# > This was not actually used to make the Herbie logo

# %%
from herbie.core import Herbie
from herbie.misc import HerbieLogo, HerbieColors, HerbieLogo2, Herbie_ascii
# Out:
# 🥳 Herbie loaded your custom templates.

# %%
H = Herbie(date="2022-04-13 00:00", model="hrrr", product="sfc", fxx=0)
H.__logo__
# Out:
# 🏋🏻‍♂️ Found 2022-Apr-13 00:00 UTC F00 [HRRR] [product=sfc] GRIB2 file from aws and index file from aws.
#
#
#
#    █ ██
#    █ ██  ┏━┓ ┏━┓            ┏━┓   ┏━┓
#    █ ██  ┃ ┃ ┃ ┃┏━━━━┓┏━┓┏━┓┃ ┃   ┏━┓┏━━━━┓
#    █ ██  ┃ ┗━┛ ┃┃ ━━ ┃┃ ┏━━┛┃ ┗━━┓┃ ┃┃ ━━ ┃
#    █ ██  ┃ ┏━┓ ┃┃ ━━━┓┃ ┃   ┃ ━━ ┃┃ ┃┃ ━━━┓
#    █ ██  ┗━┛ ┗━┛┗━━━━┛┗━┛   ┗━━━━┛┗━┛┗━━━━┛
#    █ ██
#            🏁 Retrieve NWP Model Data 🏁

# %%
HerbieLogo()
plt.savefig("../docs/_static/HerbieLogo.png", transparent=False, bbox_inches="tight")
plt.savefig(
    "../docs/_static/HerbieLogo_transparent.png", transparent=True, bbox_inches="tight"
)

# %%
HerbieLogo(white_line=True)
plt.savefig("../docs/_static/HerbieLogo_w.png", transparent=False, bbox_inches="tight")
plt.savefig(
    "../docs/_static/HerbieLogo_w_transparent.png",
    transparent=True,
    bbox_inches="tight",
)

# %%
HerbieLogo2()
plt.savefig(
    "../docs/_static/HerbieLogo2_tan.png", transparent=False, bbox_inches="tight"
)
plt.savefig(
    "../docs/_static/HerbieLogo2_tan_transparent.png",
    transparent=True,
    bbox_inches="tight",
)

# %%
HerbieLogo2(text_color="white")
plt.savefig(
    "../docs/_static/HerbieLogo2_white.png", transparent=False, bbox_inches="tight"
)
plt.savefig(
    "../docs/_static/HerbieLogo2_white_transparent.png",
    transparent=True,
    bbox_inches="tight",
)

plt.savefig(
    "../docs/_static/HerbieLogo2_white_300.png",
    transparent=False,
    bbox_inches="tight",
    dpi=300,
)
plt.savefig(
    "../docs/_static/HerbieLogo2_white_transparent_300.png",
    transparent=True,
    bbox_inches="tight",
    dpi=300,
)

# %%
HerbieLogo2(text_color="black", text_stroke=None)
plt.savefig("../docs/_static/HerbieLogo2.png", transparent=False, bbox_inches="tight")
plt.savefig(
    "../docs/_static/HerbieLogo2_transparent.png", transparent=True, bbox_inches="tight"
)

# %%
HerbieLogo2(white_line=True)
plt.savefig("../docs/_static/HerbieLogo2_w.png", transparent=False, bbox_inches="tight")
plt.savefig(
    "../docs/_static/HerbieLogo2_w_transparent.png",
    transparent=True,
    bbox_inches="tight",
)
